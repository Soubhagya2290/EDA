# %%
from sklearn import datasets
import pandas as pd

df = datasets.load_iris()

df=pd.DataFrame(df.data)
df.head()
# Out:
#      0    1    2    3
# 0  5.1  3.5  1.4  0.2
# 1  4.9  3.0  1.4  0.2
# 2  4.7  3.2  1.3  0.2
# 3  4.6  3.1  1.5  0.2
# 4  5.0  3.6  1.4  0.2

# %%
df.shape
# Out:
# (150, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       150 non-null    float64
#  1   1       150 non-null    float64
#  2   2       150 non-null    float64
#  3   3       150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
df.describe()
# Out:
#                 0           1           2           3
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.057333    3.758000    1.199333
# std      0.828066    0.435866    1.765298    0.762238
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
df.isnull().sum() ##isnull
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# dtype: int64

# %%
data = df.drop_duplicates()
data
# Out:
#        0    1    2    3
# 0    5.1  3.5  1.4  0.2
# 1    4.9  3.0  1.4  0.2
# 2    4.7  3.2  1.3  0.2
# 3    4.6  3.1  1.5  0.2
# 4    5.0  3.6  1.4  0.2
# ..   ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3
# 146  6.3  2.5  5.0  1.9
# 147  6.5  3.0  5.2  2.0
# 148  6.2  3.4  5.4  2.3
# 149  5.9  3.0  5.1  1.8
#
# [149 rows x 4 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
iris = pd.read_csv("iris3.csv")
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris['variety'].value_counts()
# Out:
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: variety, dtype: int64

# %%
iris.plot() #univariate #linegraph
# Out:
# <Axes: >

# %%
iris.plot(kind = 'scatter', x='sepal.length', y='sepal.width')
# Out:
# <Axes: xlabel='sepal.length', ylabel='sepal.width'>

# %%
sns.pairplot(iris, hue='variety', size=3)
plt.show()
# Out:
# C:\Users\Dell\anaconda3\Lib\site-packages\seaborn\axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
1. Logistic Regression - Insurance
2. Linear Regression - Home Price
3. DecisionTree - Comedian Prediction
4. SVM - Iris 
5. KNN - Movie Recommendation/ rating
6. Random Forest - Digits Data Set
7. Ensemble Learning - Diabetic Data
9. Naive Bayes - Titanic Prediction

EDA - Univeriate, Bivariate, Multivariate
Object detection - Video/image
Image Classification
